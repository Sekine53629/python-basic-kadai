# %%
"""
リスト/ディクショナリを使いこなそう
7章で学んだ知識を活かして、リストとディクショナリから特定の曜日の天気予報を取り出すプログラムを作ります。

課題の目標
本課題の目標は以下のとおりです。

Pythonでリストとディクショナリのプログラムが書けるようになること。
リストとディクショナリの違いを理解すること。
課題の内容
以下の表の内容でリスト（array）とディクショナリ（dictionary）をそれぞれ作成し、"水曜日の天気予報"を取り出して出力してください。

リスト：array
「array」という名前のリストを以下の内容で作成してください。

リストの順序	リストに入れる文字列
0	月曜日は晴れです
1	火曜日は雨です
2	水曜日は晴れです
3	木曜日は晴れです
4	金曜日は曇りです
5	土曜日は曇りのち雨です
6	日曜日は雷雨です
"""
array = ["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]

"""
ディクショナリ
「dictionary」という名前のディクショナリを以下の内容で作成してください。

キー	ディクショナリに入れる文字列
mon	晴れ
tue	雨
wed	晴れ
thu	晴れ
fri	曇り
sat	曇りのち雨
sun	雷雨
"""

dictionary = {"mon":"晴れ","tue":"雨","wed":"晴れ","thu":"晴れ","fri":"曇り","sat":"曇りのち雨","sun":"雷雨"}

"""
合格基準
本課題の目標は、課題を通して以下の項目が身についているかどうか確認することです。

Pythonでリストとディクショナリのプログラムが書けるようになること。
リストとディクショナリの違いを理解すること。
そのため、以下の項目がすべて満たされていれば合格です。

番号	合格基準
1	リストとディクショナリを正しいデータ構造で初期化されている
2	リストとディクショナリからデータを取り出して出力されている
"""

print(array[2])
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
